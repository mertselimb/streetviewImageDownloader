# %%
import shutil
import requests
API_KEY = "AIzaSyBOc1M1Uv4K3DmpQw0_DWBumITTDAVEqb4"
SIGNATURE = "9ahJFsbWIRTEh7CXV5MVbXvIebI="
URL = 'https://maps.googleapis.com/maps/api/streetview?'
SAVE_LOC = "downloads"
TYPE = ".jpeg"
SIZE = "640x640"
URL = URL + "&size=" + SIZE

# %%
class link:
    def __init__(self, address, name):
        self.address = address
        self.name = name

# %%
def createLinks(location):
    links = []
    for heading in [0,90,180,270]:
        address = URL + "&location=" + location + "&heading=" + str(heading) + "&key=" + API_KEY
        name = location + "_" + str(heading) + TYPE
        links.append(link(address,name))
    return links

# %%
def downloadImage(location):
    links = createLinks(location)
    for link in links:
        response = requests.get(link.address, stream=True)
        print("Sent GET request to " + link.address)
        print("Response " + str(response.status_code))
        if(response.status_code == 200):
            with open(SAVE_LOC + "/" +link.name, 'wb') as out_file:
                shutil.copyfileobj(response.raw, out_file)
    del response

# %%
with open('koü.txt') as f:
    lines = f.readlines()
locations = [w.replace('\n', '') for w in lines]

# %%
def percentage(part, whole):
  return str(round(100 * float(part)/float(whole), 2))
len(locations)
# Out:
# 571

# %%
i = 0
for location in locations:
    print("At " + percentage(i,len(locations)) + "% -------------------------------------------------------------")
    print("Location : " + location)
    downloadImage(location)
    i += 1
# Out:
# At 0.0%
# Location : 40.82231720,29.9324638
# Sent GET request to https://maps.googleapis.com/maps/api/streetview?&size=640x640&location=40.82231720,29.9324638&heading=0&key=AIzaSyBOc1M1Uv4K3DmpQw0_DWBumITTDAVEqb4
# Response 200
# Sent GET request to https://maps.googleapis.com/maps/api/streetview?&size=640x640&location=40.82231720,29.9324638&heading=90&key=AIzaSyBOc1M1Uv4K3DmpQw0_DWBumITTDAVEqb4
# Response 200
# Sent GET request to https://maps.googleapis.com/maps/api/streetview?&size=640x640&location=40.82231720,29.9324638&heading=180&key=AIzaSyBOc1M1Uv4K3DmpQw0_DWBumITTDAVEqb4
# Response 200
# Sent GET request to https://maps.googleapis.com/maps/api/streetview?&size=640x640&location=40.82231720,29.9324638&heading=270&key=AIzaSyBOc1M1Uv4K3DmpQw0_DWBumITTDAVEqb4
# Response 200
# At 0.18%
# Location : 40.82245110,29.9316055
# ...
